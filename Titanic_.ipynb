# %% [markdown]
# <a href="https://colab.research.google.com/github/TamaraTarasenko/Titanic/blob/main/Titanic_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Findings:
# 1. Out of 891 people on board, only 342 survived (and more than half of them were 233 women)
# 2. Our data frame has 177 missing values in the "Age" column, which is 20% of our data. Therefore, our conclusions and results will be inaccurate.
# 3. Looking at the number of deaths by class, we can say that class 3 has the highest number of deaths = 372 people out of all 891. This is almost 42%
# 4. According to the data we have, there were 7 children under 1 year old on board, and all of them survived.
# 5. There were 95 teenagers on board, 75% of whom were 18-19 years old, more than half of whom did not survive (56 people)
# 6. Sorting the data by ticket price, I noticed that there were 15 passengers with a ticket price of "0" and only one of them survived.
# And 3 people who bought the most expensive tickets for 512329200 and all three survived. They were 35-36 years old.
# 7.I found out that there were
# 377 people who had relatives on board,
# 514 people who hadn't relatives on board.
# 8. There are Survived without family = only 29,8%
#    There are Survived with family = 50/50
# 9. We see that most of the people from the 3rd classwere not able to survived (in both groups: without family and with family)
# 10. There are almost 3,5 times more men in this group (travel without family)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df_train=pd.read_csv('/content/sample_data/train.csv')
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#we check null rows in column "Age" = 177 rows  it is = 20%
df_train['Age'].isna().sum()
# Out:
# 177

# %%
df_train.plot(kind='scatter', x='Age', y='Fare')
plt.show()

# %%
df_train.sort_values('Fare').tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 299          300         1       1
# 742          743         1       1
# 311          312         1       1
# 27            28         0       1
# 88            89         1       1
# 438          439         0       1
# 341          342         1       1
# 737          738         1       1
# 258          259         1       1
# 679          680         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 742            Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 311                       Ryerson, Miss. Emily Borie  female  18.0      2
# 27                    Fortune, Mr. Charles Alexander    male  19.0      3
# 88                        Fortune, Miss. Mabel Helen  female  23.0      3
# 438                                Fortune, Mr. Mark    male  64.0      1
# ...

# %%
df_0=(df_train['Fare']==0).sum()
print(df_0)
# Out:
# 15

# %%
df_train.sort_values('Fare').head(15)
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# 263          264         0       1             Harrison, Mr. William  male
# 466          467         0       2             Campbell, Mr. William  male
# 732          733         0       2              Knight, Mr. Robert J  male
# 179          180         0       3               Leonard, Mr. Lionel  male
# ...

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
#We don't have duplicates
print(df_train.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df_train["Age"].plot(kind='hist')
plt.xlabel("Age")
#Most people were between the ages of 18 and 40
# Out:
# Text(0.5, 0, 'Age')

# %%
#
df_train.groupby('Sex')["Age"].plot(kind='kde',legend=True)
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
# averege age is = 29.69 years old
df_train['Age'].mean()
# Out:
# 29.69911764705882

# %%
from operator import index
# Most of them were male
df_train.groupby('Sex')['Age'].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
df_train['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
#the same as    df_train['Sex'].value_counts()
df_train.groupby('Sex')['Sex'].count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
#how many were Survived?
counts_Survived=df_train['Survived'].value_counts()
counts_Survived
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df_train.groupby('Survived')['Pclass'].value_counts()
# Out:
# Survived  Pclass
# 0         3         372
#           2          97
#           1          80
# 1         1         136
#           3         119
#           2          87
# Name: count, dtype: int64

# %%
#How many people were survived depending on gender "Sex"
df_Survived_Sex= df_train.groupby('Survived', as_index=False)['Sex'].value_counts()

df_Survived_Sex
# Out:
#    Survived     Sex  count
# 0         0    male    468
# 1         0  female     81
# 2         1  female    233
# 3         1    male    109

# %%
#visually it looks like this:
sns.barplot(x='Survived', y='count', hue='Sex', data=df_Survived_Sex)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
#How many people were survived depending on "Pclass"
df_Survived_Pclass= df_train.groupby('Survived', as_index=False)['Pclass'].value_counts()

df_Survived_Pclass
# Out:
#    Survived  Pclass  count
# 0         0       3    372
# 1         0       2     97
# 2         0       1     80
# 3         1       1    136
# 4         1       3    119
# 5         1       2     87

# %%
#How many children were <1
# And how many were survived?
df_children= df_train[df_train['Age']<1]
df_children
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 78   0.83      0      2  248738   29.0000      NaN        S
# 305  0.92      1      2  113781  151.5500  C22 C26        S
# 469  0.75      2      1    2666   19.2583      NaN        C
# 644  0.75      2      1    2666   19.2583      NaN        C
# ...

# %%
from operator import index
# Most of them were
df_children.groupby('Survived')['Age'].describe()
# Out:
#           count      mean       std   min   25%   50%   75%   max
# Survived
# 1           7.0  0.738571  0.161289  0.42  0.71  0.75  0.83  0.92

# %%
df_children.groupby('Survived')['Age'].count()
# Out:
# Survived
# 1    7
# Name: Age, dtype: int64

# %%
#How many teenagers
# And how many were survived?
df_teenagers= df_train[(df_train['Age']>=13) & (df_train['Age']<=19)]
df_teenagers
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 38            39         0       3    Vander Planke, Miss. Augusta Maria
# ..           ...       ...     ...                                   ...
# 853          854         1       1             Lines, Miss. Mary Conover
# 855          856         1       3            Aks, Mrs. Sam (Leah Rosen)
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
# 877          878         0       3                  Petroff, Mr. Nedelio
# 887          888         1       1          Graham, Miss. Margaret Edith
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
df_teenagers.groupby('Survived', as_index=False)['Age'].count()
# Out:
#    Survived  Age
# 0         0   56
# 1         1   39

# %%
from operator import index

df_teenagers.groupby('Survived')['Age'].describe()
# Out:
#           count       mean       std   min   25%   50%   75%   max
# Survived
# 0          56.0  17.437500  1.468031  14.0  16.0  18.0  19.0  19.0
# 1          39.0  16.897436  1.817964  13.0  16.0  17.0  18.0  19.0

# %% [markdown]
# P.S.
#
#
# Initially, I wanted to see in general whether there was a correlation between the data.
# To set this function, I had to do some manipulations, but it did not help me and then I used other methods

# %%
# 1.
#I change Male and female for 1 and 2
df_train['Sex_code']=df_train['Sex'].replace({'male':1, 'female':2})
df_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 2.
df_for_corr = df_train[['Survived', 'Age', 'Fare', 'Pclass', 'Sex_code']]
print(df_for_corr)
# Out:
#      Survived   Age     Fare  Pclass  Sex_code
# 0           0  22.0   7.2500       3         1
# 1           1  38.0  71.2833       1         2
# 2           1  26.0   7.9250       3         2
# 3           1  35.0  53.1000       1         2
# 4           0  35.0   8.0500       3         1
# ..        ...   ...      ...     ...       ...
# 886         0  27.0  13.0000       2         1
# 887         1  19.0  30.0000       1         2
# 888         0   NaN  23.4500       3         2
# 889         1  26.0  30.0000       1         1
# 890         0  32.0   7.7500       3         1
#
# [891 rows x 5 columns]

# %%
# 3.
df_for_corr.corr()
# Out:
#           Survived       Age      Fare    Pclass  Sex_code
# Survived  1.000000 -0.077221  0.257307 -0.338481  0.543351
# Age      -0.077221  1.000000  0.096067 -0.369226 -0.093254
# Fare      0.257307  0.096067  1.000000 -0.549500  0.182333
# Pclass   -0.338481 -0.369226 -0.549500  1.000000 -0.131900
# Sex_code  0.543351 -0.093254  0.182333 -0.131900  1.000000

# %%
#NEW GRAPHS
sns.barplot(x='Pclass', y='count', hue='Survived', data=df_Survived_Pclass)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
#NEW GRAPHS
counts_Survived.plot(kind='bar', color=['red', 'green'])
plt.show()

# %%
#NEW
k1=sns.kdeplot(df_for_corr['Sex_code'], shade=True)
# Out:
# <ipython-input-34-4daeaefbd2ec>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   k1=sns.kdeplot(df_for_corr['Sex_code'], shade=True)

# %% [markdown]
# ## **It was interesting for me to look at family ties.**
# **How it influenced the salvation of people.**

# %%
df_family=df_train[(df_train['SibSp']>0)|(df_train['Parch']>0)]
df_family
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 874          875         1       2
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_no_family=df_train[(df_train['SibSp']==0)&(df_train['Parch']==0)]
df_no_family
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 2              3         1       3        Heikkinen, Miss. Laina  female
# 4              5         0       3      Allen, Mr. William Henry    male
# 5              6         0       3              Moran, Mr. James    male
# 6              7         0       1       McCarthy, Mr. Timothy J    male
# 11            12         1       1      Bonnell, Miss. Elizabeth  female
# ..           ...       ...     ...                           ...     ...
# 884          885         0       3        Sutehall, Mr. Henry Jr    male
# 886          887         0       2         Montvila, Rev. Juozas    male
# 887          888         1       1  Graham, Miss. Margaret Edith  female
# 889          890         1       1         Behr, Mr. Karl Howell    male
# 890          891         0       3           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Sex_code
# ...

# %%
#404*100/533=76% We have 'Age' data
df_no_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 537 entries, 2 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  537 non-null    int64
#  1   Survived     537 non-null    int64
#  2   Pclass       537 non-null    int64
#  3   Name         537 non-null    object
#  4   Sex          537 non-null    object
#  5   Age          404 non-null    float64
#  6   SibSp        537 non-null    int64
#  7   Parch        537 non-null    int64
#  8   Ticket       537 non-null    object
#  9   Fare         537 non-null    float64
#  10  Cabin        94 non-null     object
#  11  Embarked     535 non-null    object
#  12  Sex_code     537 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 58.7+ KB

# %%
# Very wierd for me to see "Age" before 18 year old without relatives!
#I need to check Data
df_no_family["Age"].plot(kind='hist')
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
df_no_family_children= df_no_family[df_no_family['Age']<18]
df_no_family_children
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 84            85         1       2                   Ilett, Miss. Bertha
# 114          115         0       3                 Attalah, Miss. Malake
# 138          139         0       3                   Osen, Mr. Olaf Elon
# 156          157         1       3      Gilnagh, Miss. Katherine "Katie"
# 163          164         0       3                       Calic, Mr. Jovo
# 208          209         1       3             Carr, Miss. Helen "Ellen"
# 220          221         1       3        Sunderland, Mr. Victor Francis
# 282          283         0       3             de Pelsmaeker, Mr. Alfons
# 389          390         1       2                 Lehmann, Miss. Bertha
# 433          434         0       3            Kallio, Mr. Nikolai Erland
# ...

# %%
df_no_family["Age"].plot(kind='hist')
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# # There are 23 people under 18 years of age in table (df_no_family_children)
# Among them 6 childred under 16 years old.
# So In our Data we have  20%  null rows in column "Age" = 177 rows and some children travelled only with nanny, therefore parch= 0 for them

# %%
df_no_family_children=(df_no_family['Age']<18).sum()
print(df_no_family_children)
# Out:
# 23

# %%
df_no_family_children=(df_no_family['Age']<16).sum()
print(df_no_family_children)
# Out:
# 6

# %%
#31000/354=88% We have "Age" Data
df_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 354 entries, 0 to 888
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  354 non-null    int64
#  1   Survived     354 non-null    int64
#  2   Pclass       354 non-null    int64
#  3   Name         354 non-null    object
#  4   Sex          354 non-null    object
#  5   Age          310 non-null    float64
#  6   SibSp        354 non-null    int64
#  7   Parch        354 non-null    int64
#  8   Ticket       354 non-null    object
#  9   Fare         354 non-null    float64
#  10  Cabin        110 non-null    object
#  11  Embarked     354 non-null    object
#  12  Sex_code     354 non-null    int64
# dtypes: float64(2), int64(6), object(5)
# memory usage: 38.7+ KB

# %%
#This picture was expected

df_family["Age"].plot(kind='hist')
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
#Now we have table with all children under 18 years old
df_family=df_train[(df_train['SibSp']>0)|(df_train['Parch']>0) |(df_train['Age']<18)]
df_family
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#now we have 514 people more then 18 years old without family
#23 children with nani we include here aand we can work with this Data
df_no_family1=df_train[(df_train['SibSp']==0)&(df_train['Parch']==0)&((df_train['Age']>=18)|(df_train['Age'].isna())) ]
df_no_family1
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 2              3         1       3        Heikkinen, Miss. Laina  female
# 4              5         0       3      Allen, Mr. William Henry    male
# 5              6         0       3              Moran, Mr. James    male
# 6              7         0       1       McCarthy, Mr. Timothy J    male
# 11            12         1       1      Bonnell, Miss. Elizabeth  female
# ..           ...       ...     ...                           ...     ...
# 884          885         0       3        Sutehall, Mr. Henry Jr    male
# 886          887         0       2         Montvila, Rev. Juozas    male
# 887          888         1       1  Graham, Miss. Margaret Edith  female
# 889          890         1       1         Behr, Mr. Karl Howell    male
# 890          891         0       3           Dooley, Mr. Patrick    male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  Sex_code
# ...

# %%
df_no_family1["Age"].plot(kind='hist')
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
#how many were Survived in df_family 50/50 !!!
counts_Family_Survived=df_family['Survived'].value_counts()
counts_Family_Survived
# Out:
# Survived
# 1    189
# 0    188
# Name: count, dtype: int64

# %%
counts_Family_Survived.plot(kind='bar', color=['red', 'green'])
plt.show()

# %%
#how many were Survived in df_no_family = only 29,8%
counts_No_Family_Survived=df_no_family1['Survived'].value_counts()
counts_No_Family_Survived
# Out:
# Survived
# 0    361
# 1    153
# Name: count, dtype: int64

# %%
counts_No_Family_Survived.plot(kind='bar', color=['red', 'blue'])
plt.show()

# %% [markdown]
# # I try to find something interesting :)

# %%
df_family['Sex'].value_counts()
# Out:
# Sex
# female    199
# male      178
# Name: count, dtype: int64

# %%
#There are almost 3,5 times more men in this group (travel without family)
df_no_family1['Sex'].value_counts()
# Out:
# Sex
# male      399
# female    115
# Name: count, dtype: int64

# %%
#How many people were survived depending on "Pclass"
df_family_Survived_Pclass= df_family.groupby('Survived', as_index=False)['Pclass'].value_counts()

df_family_Survived_Pclass
# Out:
#    Survived  Pclass  count
# 0         0       3    128
# 1         0       2     31
# 2         0       1     29
# 3         1       1     79
# 4         1       3     57
# 5         1       2     53

# %%
sns.barplot(x='Pclass', y='count', hue='Survived', data=df_family_Survived_Pclass)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
#How many people were survived depending on "Pclass"
df_no_family1_Survived_Pclass= df_no_family1.groupby('Survived', as_index=False)['Pclass'].value_counts()

df_no_family1_Survived_Pclass
# Out:
#    Survived  Pclass  count
# 0         0       3    244
# 1         0       2     66
# 2         0       1     51
# 3         1       3     62
# 4         1       1     57
# 5         1       2     34

# %%
sns.barplot(x='Pclass', y='count', hue='Survived', data=df_no_family1_Survived_Pclass)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>
